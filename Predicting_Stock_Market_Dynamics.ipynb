# %% [markdown]
# # DataPreprocessing

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Stock_Market_Data.csv")
df
# Out:
#             Date     Low    Open   Volume   High   Close  Adjusted Close
# 0     11-02-1992  4.5000  4.5000  1509200  5.250  5.0625        4.885583
# 1     12-02-1992  4.8750  5.0625   869000  5.500  5.3750        5.187162
# 2     13-02-1992  4.9375  5.3125   177000  5.375  5.0000        4.825266
# 3     14-02-1992  4.8750  5.0625   201000  5.375  5.0625        4.885583
# 4     18-02-1992  5.0000  5.1875   266200  5.375  5.1250        4.945898
# ...          ...     ...     ...      ...    ...     ...             ...
# 7762  05-12-2022  0.3300  0.3300     3500  0.330  0.3300        0.330000
# 7763  06-12-2022  0.3300  0.3300      100  0.330  0.3300        0.330000
# 7764  07-12-2022  0.3800  0.3800      100  0.380  0.3800        0.380000
# 7765  08-12-2022  0.4000  0.4000     1000  0.400  0.4000        0.400000
# 7766  09-12-2022  0.3500  0.3500       10  0.350  0.3500        0.350000
#
# [7767 rows x 7 columns]

# %%
df.head()
# Out:
#         Date     Low    Open   Volume   High   Close  Adjusted Close
# 0 1992-02-11  4.5000  4.5000  1509200  5.250  5.0625        4.885583
# 1 1992-02-12  4.8750  5.0625   869000  5.500  5.3750        5.187162
# 2 1992-02-13  4.9375  5.3125   177000  5.375  5.0000        4.825266
# 3 1992-02-14  4.8750  5.0625   201000  5.375  5.0625        4.885583
# 4 1992-02-18  5.0000  5.1875   266200  5.375  5.1250        4.945898

# %%
df.tail()
# Out:
#            Date   Low  Open  Volume  High  Close  Adjusted Close
# 7762 2022-12-05  0.33  0.33    3500  0.33   0.33            0.33
# 7763 2022-12-06  0.33  0.33     100  0.33   0.33            0.33
# 7764 2022-12-07  0.38  0.38     100  0.38   0.38            0.38
# 7765 2022-12-08  0.40  0.40    1000  0.40   0.40            0.40
# 7766 2022-12-09  0.35  0.35      10  0.35   0.35            0.35

# %%
df.shape
# Out:
# (7767, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7767 entries, 0 to 7766
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Date            7767 non-null   datetime64[ns]
#  1   Low             7767 non-null   float64
#  2   Open            7767 non-null   float64
#  3   Volume          7767 non-null   int64
#  4   High            7767 non-null   float64
#  5   Close           7767 non-null   float64
#  6   Adjusted Close  7767 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 424.9 KB

# %%
df.describe()
# Out:
#                                 Date          Low         Open        Volume  \
# count                           7767  7767.000000  7767.000000  7.767000e+03
# mean   2007-07-09 02:35:21.900347648     3.614005     3.723125  6.150173e+04
# min              1992-02-11 00:00:00     0.070000     0.080000  0.000000e+00
# 25%              1999-10-18 12:00:00     0.600000     0.620000  1.090000e+04
# 50%              2007-07-11 00:00:00     3.350000     3.450000  3.000000e+04
# 75%              2015-03-26 12:00:00     5.320000     5.485000  7.045000e+04
# max              2022-12-09 00:00:00    14.375000    15.250000  3.346900e+06
# std                              NaN     3.010921     3.094238  1.212415e+05
#
#               High        Close  Adjusted Close
# count  7767.000000  7767.000000     7767.000000
# mean      3.835445     3.729117        3.618044
# min       0.100000     0.080000        0.080000
# 25%       0.650000     0.630000        0.623642
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Low', 'Open', 'Volume', 'High', 'Close', 'Adjusted Close'], dtype='object')

# %%
df["High"].mode()
# Out:
# 0    5.0
# Name: High, dtype: float64

# %%
df["Open"].value_counts()
# Out:
# Open
# 5.00000    96
# 0.31000    89
# 0.20000    80
# 0.30000    77
# 0.23000    69
#            ..
# 8.03000     1
# 8.27000     1
# 8.31000     1
# 5.92000     1
# 2.46875     1
# Name: count, Length: 1073, dtype: int64

# %% [markdown]
# # Data Visualizations

# %%
import pandas as pd
import matplotlib as plt
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


df = pd.read_csv('Stock_Market_Data.csv')

df['Date'] = pd.to_datetime(df['Date'], dayfirst=True)
df.set_index('Date', inplace=True)
yearly_data = df.resample('Y').mean()  
yearly_data.to_csv('yearly_stock_data.csv')
plt.figure(figsize=(10, 6))
plt.bar(yearly_data.index.year, yearly_data['Volume'], color='skyblue')
plt.title('Average Volume Traded Per Year')
plt.xlabel('Year')
plt.ylabel('Average Volume')
plt.xticks(yearly_data.index.year, rotation=45) 

plt.tight_layout() 
plt.savefig("100.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Stock_Market_Data.csv')
data['Date'] = pd.to_datetime(data['Date'], dayfirst = True)
start_year = 2018
end_year = 2020
data = data[(data['Date'].dt.year >= start_year) & (data['Date'].dt.year <= end_year)]
data = data.sort_values(by='Date')
plt.figure(figsize=(10, 6))
plt.plot(data['Date'], data['Close'], color='blue', linestyle='-', label='Low Price')
plt.plot(data['Date'], data['Adjusted Close'], color='red', linestyle='-', label='High Price')
plt.title(f'Trend of Close and Adjusted Close Prices Over Time ({start_year}-{end_year})')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend() 
plt.grid(True)
plt.savefig("101.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('Stock_Market_Data.csv')

plt.figure(figsize=(10, 6))
plt.hist(df['Volume'], bins=50, color='green', edgecolor='black')
plt.title('Histogram of Trading Volume')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.grid(True)
plt.savefig("103.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("Stock_Market_Data.csv")
data['Date'] = pd.to_datetime(data['Date'], dayfirst = True)

plt.figure(figsize=(10, 6))
plt.scatter(data['Low'], data['High'], color='red', alpha=0.5)
plt.title('Relationship between Low and High Prices')
plt.xlabel('Low Price')
plt.ylabel('High Price')
plt.savefig("107.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('Stock_Market_Data.csv')

scaled_volume = data['Volume'] / data['Volume'].max() * 100
plt.scatter(data['Open'], data['Close'], s=scaled_volume, alpha=0.3, color='skyblue')
plt.title('Relationship Between Opening Prices, Closing Prices, and Trading Volume')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.grid(True)
plt.savefig("106.png")
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

data = pd.read_csv('Stock_Market_Data.csv')

plt.figure(figsize=(10, 6))
plt.scatter(data['Open'], data['Close'], color='blue', alpha=0.5)
coefficients = np.polyfit(data['Open'], data['Close'], 1)
polynomial = np.poly1d(coefficients)
x_values = np.linspace(min(data['Open']), max(data['Open']), 100)
plt.plot(x_values, polynomial(x_values), color='red', linestyle='--')

plt.title('Relationship Between Opening Prices and Closing Prices')
plt.xlabel('Opening Price')
plt.ylabel('Closing Price')
plt.grid(True)
plt.savefig("102.png")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('Stock_Market_Data.csv')
data['Date'] = pd.to_datetime(data['Date'], dayfirst = True)
data = data.sort_values(by='Date')
plt.figure(figsize=(12, 6))
plt.fill_between(data['Date'], data['Close'], color="skyblue", alpha=0.4)
plt.plot(data['Date'], data['Close'], color="Slateblue", alpha=0.6, linewidth=2)
plt.title('Trend of Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price')
plt.grid(True)
plt.savefig("105.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Stock_Market_Data.csv")
data['Date'] = pd.to_datetime(data['Date'], dayfirst = True)
data['Year'] = data['Date'].dt.year
start_year = 2010
end_year = 2015
filtered_data = data[(data['Year'] >= start_year) & (data['Year'] <= end_year)]
box_color = 'lightblue'
plt.figure(figsize=(10, 6))
plt.boxplot(filtered_data['Adjusted Close'], boxprops=dict(color=box_color))
plt.title(f'Box Plot of Adjusted Closing Prices ({start_year}-{end_year})')
plt.xlabel('Adjusted Closing Price')
plt.savefig("104.png")
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("Stock_Market_Data.csv")
ax = data.plot.box(figsize=(10, 6), grid=True)
ax.set_title('Box plot of Stock Market Data')
ax.set_xlabel('Columns')
ax.set_ylabel('Values')

plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('Stock_Market_Data.csv') 
df['Date'] = pd.to_datetime(df['Date'], dayfirst = True)
print(df.head())
correlation_matrix = df.corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap of Stock Market Dataset')
plt.savefig('108.png')
plt.show()
# Out:
#         Date     Low    Open   Volume   High   Close  Adjusted Close
# 0 1992-02-11  4.5000  4.5000  1509200  5.250  5.0625        4.885583
# 1 1992-02-12  4.8750  5.0625   869000  5.500  5.3750        5.187162
# 2 1992-02-13  4.9375  5.3125   177000  5.375  5.0000        4.825266
# 3 1992-02-14  4.8750  5.0625   201000  5.375  5.0625        4.885583
# 4 1992-02-18  5.0000  5.1875   266200  5.375  5.1250        4.945898

# %% [markdown]
# # ML model creation

# %% [markdown]
# ## LOAD DATA

# %%
import pandas as pd
df=pd.read_csv("Stock_Market_Data.csv")

# %% [markdown]
# ## DATA PREPARATION

# %%
df
# Out:
#             Date     Low    Open   Volume   High   Close  Adjusted Close
# 0     11-02-1992  4.5000  4.5000  1509200  5.250  5.0625        4.885583
# 1     12-02-1992  4.8750  5.0625   869000  5.500  5.3750        5.187162
# 2     13-02-1992  4.9375  5.3125   177000  5.375  5.0000        4.825266
# 3     14-02-1992  4.8750  5.0625   201000  5.375  5.0625        4.885583
# 4     18-02-1992  5.0000  5.1875   266200  5.375  5.1250        4.945898
# ...          ...     ...     ...      ...    ...     ...             ...
# 7762  05-12-2022  0.3300  0.3300     3500  0.330  0.3300        0.330000
# 7763  06-12-2022  0.3300  0.3300      100  0.330  0.3300        0.330000
# 7764  07-12-2022  0.3800  0.3800      100  0.380  0.3800        0.380000
# 7765  08-12-2022  0.4000  0.4000     1000  0.400  0.4000        0.400000
# 7766  09-12-2022  0.3500  0.3500       10  0.350  0.3500        0.350000
#
# [7767 rows x 7 columns]

# %% [markdown]
# ### DATA SEPERATION AS X AND Y

# %%
df.isnull().sum()
# Out:
# Date              0
# Low               0
# Open              0
# Volume            0
# High              0
# Close             0
# Adjusted Close    0
# dtype: int64

# %%
features = ['Low', 'Open', 'Volume', 'High']
target = 'Close'
x=df[features]
y=df[target]

# %% [markdown]
# ### DATA SPLITTING

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
x_train
# Out:
#           Low    Open  Volume    High
# 5083  11.0500  11.060  126800  11.420
# 6858   0.2800   0.300   63300   0.300
# 399   13.2500  13.250   16700  13.875
# 3270   0.6300   0.630    8700   0.850
# 5561   3.4600   3.500  129200   3.600
# ...       ...     ...     ...     ...
# 79     4.1875   4.375    7400   4.375
# 3927   3.7800   3.780   20300   3.930
# 5955   0.1100   0.110   96600   0.120
# 6936   0.2600   0.260   19900   0.280
# 5640   2.4700   2.670  811600   2.860
#
# [6213 rows x 4 columns]

# %%
x_test
# Out:
#          Low    Open  Volume   High
# 446   12.250  12.750   51400  12.75
# 5410   8.080   8.540   95000   8.61
# 5253   7.590   7.690   57900   7.73
# 5063   8.950   9.270  124800   9.41
# 6998   0.280   0.320   46000   0.33
# ...      ...     ...     ...    ...
# 7549   0.520   0.520    5700   0.56
# 4016   5.020   5.250   10400   5.58
# 1129   5.375   5.375   61100   6.00
# 6689   0.260   0.290   62900   0.30
# 7665   0.540   0.540     200   0.58
#
# [1554 rows x 4 columns]

# %% [markdown]
# ### LINEAR REGRESSION

# %% [markdown]
# #### **TRAINING THE MODEL**

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ####**APPLYING THE MODEL TO MAKE A PREDICTION**

# %%
y_lr_train_pred=lr.predict(x_train)
y_lr_test_pred=lr.predict(x_test)

# %%
len(y_lr_train_pred)
# Out:
# 6213

# %%
y_lr_test_pred
# Out:
# array([12.4037424 ,  8.27920392,  7.64055089, ...,  5.81651179,
#         0.28111143,  0.57206142])

# %% [markdown]
# #### **EVALUTING MODEL PERFORMANCE**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

lr_train_mse=mean_squared_error(y_train,y_lr_train_pred)
lr_train_r2=r2_score(y_train,y_lr_train_pred)
lr_train_mae = mean_absolute_error(y_test, y_lr_test_pred)

lr_test_mse=mean_squared_error(y_test,y_lr_test_pred)
lr_test_r2=r2_score(y_test,y_lr_test_pred)
lr_test_mae = mean_absolute_error(y_test, y_lr_test_pred)

# %%
lr_train_mse
# Out:
# 0.009160734640175186

# %%
lr_train_r2
# Out:
# 0.9990346048578589

# %%
print("LR MSE (TRAIN):",lr_train_mse)
print("LR R2 (TRAIN):",lr_train_r2)
print("LR MSE (TEST):",lr_test_mse)
print("LR R2 (TEST):",lr_test_r2)
# Out:
# LR MSE (TRAIN): 0.009160734640175186
# LR R2 (TRAIN): 0.9990346048578589
# LR MSE (TEST): 0.009022370595680151
# LR R2 (TEST): 0.9990845037521605

# %%
lr_results=pd.DataFrame(["Linear Regression",lr_train_mse,lr_train_r2,lr_train_mae,lr_test_mse,lr_test_r2,lr_test_mae]).transpose()
lr_results.columns=['METHOD','TRAINING MSE','TRAINING R2','TRAINING MAE','TEST MSE','TEST R2','TEST MAE']

# %%
lr_results
# Out:
#               METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE  \
# 0  Linear Regression     0.009161    0.999035     0.057853  0.009022
#
#     TEST R2  TEST MAE
# 0  0.999085  0.057853

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 6))
sns.regplot(x=y_test, y=y_lr_test_pred, line_kws={"color": "red"})
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.savefig('regplot.png')
plt.show()

# %% [markdown]
# ### RANDOM FOREST

# %% [markdown]
# #### **TRAINING THE MODEL**

# %%
from sklearn.ensemble import RandomForestRegressor

rf = RandomForestRegressor(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %% [markdown]
# #### **APPLYING THE MODEL TO MAKE A PREDICTION**

# %%
y_rf_train_pred=rf.predict(x_train)
y_rf_test_pred=rf.predict(x_test)

# %%
y_rf_test_pred
# Out:
# array([12.37625   ,  8.25867501,  7.66939996, ...,  5.80806875,
#         0.2864    ,  0.5648    ])

# %% [markdown]
# #### **EVALUTING MODEL PERFORMANCE**

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

rf_train_mse=mean_squared_error(y_train,y_rf_train_pred)
rf_train_r2=r2_score(y_train,y_rf_train_pred)
rf_train_mae = mean_absolute_error(y_test, y_rf_test_pred)

rf_test_mse=mean_squared_error(y_test,y_rf_test_pred)
rf_test_r2=r2_score(y_test,y_rf_test_pred)
rf_test_mae = mean_absolute_error(y_test, y_rf_test_pred)

# %%
rf_results=pd.DataFrame(["Random Forest Regression",rf_train_mse,rf_train_r2,rf_test_mae,rf_test_mse,rf_test_r2,rf_test_mae]).transpose()
rf_results.columns=['METHOD','TRAINING MSE','TRAINING R2','TRAINING MAE','TEST MSE','TEST R2','TEST MAE']
rf_results
# Out:
#                      METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE  \
# 0  Random Forest Regression     0.001651    0.999826     0.065402  0.012412
#
#     TEST R2  TEST MAE
# 0  0.998741  0.065402

# %% [markdown]
# ### MODEL COMPARISION

# %%
df_models=pd.concat([lr_results,rf_results],axis=0).reset_index(drop=True)
df_models
# Out:
#                      METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE  \
# 0         Linear Regression     0.009161    0.999035     0.057853  0.009022
# 1  Random Forest Regression     0.001651    0.999826     0.065402  0.012412
#
#     TEST R2  TEST MAE
# 0  0.999085  0.057853
# 1  0.998741  0.065402

# %%
y_test
# Out:
# 446     12.25
# 5410     8.14
# 5253     7.67
# 5063     9.41
# 6998     0.33
#         ...
# 7549     0.56
# 4016     5.02
# 1129     5.75
# 6689     0.28
# 7665     0.58
# Name: Close, Length: 1554, dtype: float64

# %%
y_rf_train_pred
# Out:
# array([11.27822507,  0.2838    , 13.66      , ...,  0.1197    ,
#         0.2788    ,  2.74031251])

# %%
import matplotlib.pyplot as plt

sns.regplot(x=y_test, y=y_rf_test_pred, data=rf_results, line_kws={"color": "red"})
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted with Regression Line')
plt.savefig('rf.png')
plt.show()

# %% [markdown]
# # Support Vector Machines (SVMs)

# %%
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
svm = SVR(kernel='rbf', C=100, gamma=0.1)
svm.fit(X_train_scaled, y_train)

y_svm_test_pred = svm.predict(X_test_scaled)
y_svm_train_pred = svm.predict(X_train_scaled)

# %%
y_svm_test_pred
# Out:
# array([12.37969735,  8.25182014,  7.64889847, ...,  5.80353855,
#         0.30812685,  0.57079964])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

tr_mse_svm = mean_squared_error(y_train, y_svm_train_pred)
tr_mae_svm = mean_absolute_error(y_train, y_svm_train_pred)
tr_r2_svm = r2_score(y_train, y_svm_train_pred)

ts_mse_svm = mean_squared_error(y_test, y_svm_test_pred)
ts_mae_svm = mean_absolute_error(y_test, y_svm_test_pred)
ts_r2_svm = r2_score(y_test, y_svm_test_pred)

# %%
import pandas as pd
svm_results = pd.DataFrame(["Support Vector Machine", tr_mse_svm, tr_mae_svm, tr_r2_svm,ts_mse_svm, ts_mae_svm, ts_r2_svm]).transpose()
svm_results.columns = ['METHOD','TRAINING MSE','TRAINING R2','TRAINING MAE','TEST MSE','TEST R2','TEST MAE']

# %%
svm_results
# Out:
#                    METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE  \
# 0  Support Vector Machine     0.008792    0.063748     0.999073  0.011202
#
#     TEST R2  TEST MAE
# 0  0.065389  0.998863

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.regplot(x=y_train, y=y_svm_train_pred, data=svm_results, line_kws={"color": "red"})
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted with Regression Line')
plt.savefig('svm_regplot.png')
plt.show()

# %% [markdown]
# ## K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(x_train)
X_test_scaled = scaler.transform(x_test)

# %%
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train_scaled, y_train)

y_knn_test_pred = knn.predict(X_test_scaled)
y_knn_train_pred = knn.predict(X_train_scaled)

# %%
y_knn_test_pred
# Out:
# array([12.4       ,  8.43000011,  7.71899996, ...,  5.61350002,
#         0.28      ,  0.55000001])

# %%
tr_mse_knn = mean_squared_error(y_train, y_knn_train_pred)
tr_mae_knn = mean_absolute_error(y_train, y_knn_train_pred)
tr_r2_knn = r2_score(y_train, y_knn_train_pred)

ts_mse_knn = mean_squared_error(y_test, y_knn_test_pred)
ts_mae_knn = mean_absolute_error(y_test, y_knn_test_pred)
ts_r2_knn = r2_score(y_test, y_knn_test_pred)

# %%
knn_results = pd.DataFrame(["KNN", tr_mse_knn, tr_mae_knn, tr_r2_knn,ts_mse_knn, ts_mae_knn, ts_r2_knn]).transpose()
knn_results.columns = ['METHOD','TRAINING MSE','TRAINING R2','TRAINING MAE','TEST MSE','TEST R2','TEST MAE']
print("KNN Model Evaluation Metrics:")
knn_results
# Out:
# KNN Model Evaluation Metrics:
#   METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE   TEST R2  TEST MAE
# 0    KNN     0.017235    0.067665     0.998184  0.044488  0.086022  0.995486

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.regplot(x=y_train, y=y_knn_train_pred, data=knn_results, line_kws={"color": "red"})
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.title('Actual vs Predicted with Regression Line')
plt.savefig('knn.png')
plt.show()

# %% [markdown]
# ## MODEL COMPARISION

# %%
df_models=pd.concat([lr_results,svm_results,rf_results,knn_results],axis=0).reset_index(drop=True)
df_models
# Out:
#                      METHOD TRAINING MSE TRAINING R2 TRAINING MAE  TEST MSE  \
# 0         Linear Regression     0.009161    0.999035     0.057853  0.009022
# 1    Support Vector Machine     0.008792    0.063748     0.999073  0.011202
# 2  Random Forest Regression     0.001651    0.999826     0.065402  0.012412
# 3                       KNN     0.017235    0.067665     0.998184  0.044488
#
#     TEST R2  TEST MAE
# 0  0.999085  0.057853
# 1  0.065389  0.998863
# 2  0.998741  0.065402
# 3  0.086022  0.995486

# %%
best_model_test_mse = df_models.loc[df_models['TEST MSE'].astype(float).idxmin()]['METHOD']
best_model_test_mae = df_models.loc[df_models['TEST MAE'].astype(float).idxmin()]['METHOD']
best_model_test_r2 = df_models.loc[df_models['TEST R2'].astype(float).idxmax()]['METHOD']


print(f"The best model based on TEST MSE is: {best_model_test_mse}")
print(f"The best model based on TEST MAE is: {best_model_test_mae}")
print(f"The best model based on TEST R2 is: {best_model_test_r2}")
# Out:
# The best model based on TEST MSE is: Linear Regression
# The best model based on TEST MAE is: Linear Regression
# The best model based on TEST R2 is: Linear Regression

# %%
input_features = pd.DataFrame([[12.250, 12.750, 51400, 12.75]], columns=features)
rf.predict(input_features)
# Out:
# array([12.37625])
